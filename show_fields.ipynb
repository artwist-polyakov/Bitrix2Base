# %%
import requests
import yaml

def show_fields():
    with open('config.yaml', 'r') as file:
        config = yaml.safe_load(file)
    URL = config['b24_key']
    r = requests.get(URL+'task.item.userfield.getfields')
    print(r.json())


    for table_type in config['table_names'].keys():
        requestURL = URL + f'crm.{table_type}.fields'
        r = requests.get(requestURL)
        print(table_type.capitalize() + " fields:")
        print("=========================")
        result = r.json()['result']
        # userfields = {element['FIELD_NAME']: for element in requests.get(URL+f'crm.{table_type}.userfield.list').json()['result']}
        for field_name in result.keys():
            title = result[field_name]['title']
            print(f'Field name:{field_name}, field title: {title}')
        print("=========================")



show_fields()

if __name__ == "__main__":
    show_values()
# Out:
# {'error': 'insufficient_scope', 'error_description': 'The request requires higher privileges than provided by the webhook token'}
# Deal fields:
# =========================
# Field name:ID, field title: ID
# Field name:TITLE, field title: Название
# Field name:TYPE_ID, field title: Тип
# Field name:CATEGORY_ID, field title: Направление
# Field name:STAGE_ID, field title: Стадия сделки
# Field name:STAGE_SEMANTIC_ID, field title: Группа стадии
# Field name:IS_NEW, field title: Новая сделка
# Field name:IS_RECURRING, field title: Регулярная сделка
# Field name:IS_RETURN_CUSTOMER, field title: Повторная сделка
# Field name:IS_REPEATED_APPROACH, field title: Повторное обращение
# Field name:PROBABILITY, field title: Вероятность
# Field name:CURRENCY_ID, field title: Валюта
# Field name:OPPORTUNITY, field title: Сумма
# Field name:IS_MANUAL_OPPORTUNITY, field title: IS_MANUAL_OPPORTUNITY
# Field name:TAX_VALUE, field title: Ставка налога
# Field name:COMPANY_ID, field title: Компания
# Field name:CONTACT_ID, field title: Контакт
# Field name:CONTACT_IDS, field title: Контакты
# Field name:QUOTE_ID, field title: Предложение
# Field name:BEGINDATE, field title: Дата начала
# Field name:CLOSEDATE, field title: Дата завершения
# Field name:OPENED, field title: Доступна для всех
# Field name:CLOSED, field title: Закрыта
# Field name:COMMENTS, field title: Комментарий
# Field name:ASSIGNED_BY_ID, field title: Ответственный
# Field name:CREATED_BY_ID, field title: Кем создана
# Field name:MODIFY_BY_ID, field title: Кем изменена
# Field name:MOVED_BY_ID, field title: MOVED_BY_ID
# Field name:DATE_CREATE, field title: Дата создания
# Field name:DATE_MODIFY, field title: Дата изменения
# Field name:MOVED_TIME, field title: MOVED_TIME
# Field name:SOURCE_ID, field title: Источник
# Field name:SOURCE_DESCRIPTION, field title: Дополнительно об источнике
# Field name:LEAD_ID, field title: Лид
# Field name:ADDITIONAL_INFO, field title: Дополнительная информация
# Field name:LOCATION_ID, field title: Местоположение
# Field name:ORIGINATOR_ID, field title: Внешний источник
# Field name:ORIGIN_ID, field title: Идентификатор элемента во внешнем источнике
# Field name:UTM_SOURCE, field title: Рекламная система
# Field name:UTM_MEDIUM, field title: Тип трафика
# Field name:UTM_CAMPAIGN, field title: Обозначение рекламной кампании
# Field name:UTM_CONTENT, field title: Содержание кампании
# Field name:UTM_TERM, field title: Условие поиска кампании
# Field name:UF_CRM_1613562115, field title: UF_CRM_1613562115
# Field name:UF_CRM_1613563567, field title: UF_CRM_1613563567
# Field name:UF_CRM_1614608584, field title: UF_CRM_1614608584
# Field name:UF_CRM_1614676411, field title: UF_CRM_1614676411
# Field name:UF_CRM_1614679044, field title: UF_CRM_1614679044
# Field name:UF_CRM_1615800676, field title: UF_CRM_1615800676
# Field name:UF_STATUS_ZAKAZA_1C, field title: UF_STATUS_ZAKAZA_1C
# Field name:UF_SOZDAVAT_ZAKAZ_1C, field title: UF_SOZDAVAT_ZAKAZ_1C
# Field name:UF_ZAKAZ_1C, field title: UF_ZAKAZ_1C
# Field name:UF_SOURCE_AUTO, field title: UF_SOURCE_AUTO
# Field name:UF_CRM_YMCLIENTID, field title: UF_CRM_YMCLIENTID
# Field name:UF_CRM_1626387863, field title: UF_CRM_1626387863
# Field name:UF_CRM_1626388093, field title: UF_CRM_1626388093
# Field name:UF_CRM_1626388103, field title: UF_CRM_1626388103
# Field name:UF_CRM_1626388465, field title: UF_CRM_1626388465
# Field name:UF_CRM_1626388473, field title: UF_CRM_1626388473
# Field name:UF_CRM_1633944990679, field title: UF_CRM_1633944990679
# Field name:UF_CRM_1633947535725, field title: UF_CRM_1633947535725
# Field name:UF_CRM_1633947610652, field title: UF_CRM_1633947610652
# Field name:UF_CRM_1633947930744, field title: UF_CRM_1633947930744
# Field name:UF_CRM_1633954572212, field title: UF_CRM_1633954572212
# Field name:UF_CRM_1633954591365, field title: UF_CRM_1633954591365
# Field name:UF_CRM_1633954602737, field title: UF_CRM_1633954602737
# Field name:UF_CRM_1633954682938, field title: UF_CRM_1633954682938
# Field name:UF_CRM_1633969782, field title: UF_CRM_1633969782
# Field name:UF_CRM_1634038494, field title: UF_CRM_1634038494
# Field name:UF_CRM_1634038523, field title: UF_CRM_1634038523
# Field name:UF_CRM_1634293510, field title: UF_CRM_1634293510
# Field name:UF_CRM_62FE345E93E8C, field title: UF_CRM_62FE345E93E8C
# Field name:UF_CLIENT_IP, field title: UF_CLIENT_IP
# Field name:UF_CRM_MGO_CC_ENTRY_ID, field title: UF_CRM_MGO_CC_ENTRY_ID
# Field name:UF_CRM_MGO_CC_CHANNEL_TYPE, field title: UF_CRM_MGO_CC_CHANNEL_TYPE
# Field name:UF_CRM_MGO_CC_RESULT, field title: UF_CRM_MGO_CC_RESULT
# Field name:UF_CRM_MGO_CC_ENTRY_POINT, field title: UF_CRM_MGO_CC_ENTRY_POINT
# Field name:UF_CRM_MGO_CC_CREATE, field title: UF_CRM_MGO_CC_CREATE
# Field name:UF_CRM_MGO_CC_END, field title: UF_CRM_MGO_CC_END
# Field name:UF_CRM_MGO_CC_TAG_ID, field title: UF_CRM_MGO_CC_TAG_ID
# Field name:UF_CRM_603F9087727CF, field title: UF_CRM_603F9087727CF
# Field name:UF_CRM_603F90878854E, field title: UF_CRM_603F90878854E
# Field name:UF_CRM_603F9087B3A1A, field title: UF_CRM_603F9087B3A1A
# Field name:UF_CRM_603F9087BD5EA, field title: UF_CRM_603F9087BD5EA
# Field name:UF_CRM_CALLTOUCHA8VI, field title: UF_CRM_CALLTOUCHA8VI
# Field name:UF_CRM_CALLTOUCHNEAQ, field title: UF_CRM_CALLTOUCHNEAQ
# Field name:UF_CRM_CALLTOUCHJLMM, field title: UF_CRM_CALLTOUCHJLMM
# Field name:UF_CRM_CALLTOUCHMC8V, field title: UF_CRM_CALLTOUCHMC8V
# =========================
# Lead fields:
# =========================
# Field name:ID, field title: ID
# Field name:TITLE, field title: Название лида
# Field name:HONORIFIC, field title: Обращение
# Field name:NAME, field title: Имя
# Field name:SECOND_NAME, field title: Отчество
# Field name:LAST_NAME, field title: Фамилия
# Field name:BIRTHDATE, field title: Дата рождения
# Field name:COMPANY_TITLE, field title: Название компании
# Field name:SOURCE_ID, field title: Источник
# Field name:SOURCE_DESCRIPTION, field title: Дополнительно об источнике
# Field name:STATUS_ID, field title: Статус
# Field name:STATUS_DESCRIPTION, field title: Дополнительно о статусе
# Field name:STATUS_SEMANTIC_ID, field title: Состояние статуса
# Field name:POST, field title: Должность
# Field name:ADDRESS, field title: Адрес
# Field name:ADDRESS_2, field title: Адрес (стр. 2)
# Field name:ADDRESS_CITY, field title: Город
# Field name:ADDRESS_POSTAL_CODE, field title: Почтовый индекс
# Field name:ADDRESS_REGION, field title: Район
# Field name:ADDRESS_PROVINCE, field title: Область
# Field name:ADDRESS_COUNTRY, field title: Страна
# Field name:ADDRESS_COUNTRY_CODE, field title: Код страны
# Field name:ADDRESS_LOC_ADDR_ID, field title: Идентификатор адреса местоположения
# Field name:CURRENCY_ID, field title: Валюта
# Field name:OPPORTUNITY, field title: Сумма
# Field name:IS_MANUAL_OPPORTUNITY, field title: IS_MANUAL_OPPORTUNITY
# Field name:OPENED, field title: Доступен для всех
# Field name:COMMENTS, field title: Комментарий
# Field name:HAS_PHONE, field title: Задан телефон
# Field name:HAS_EMAIL, field title: Задан e-mail
# Field name:HAS_IMOL, field title: Задана открытая линия
# Field name:ASSIGNED_BY_ID, field title: Ответственный
# Field name:CREATED_BY_ID, field title: Кем создан
# Field name:MODIFY_BY_ID, field title: Кем изменен
# Field name:MOVED_BY_ID, field title: MOVED_BY_ID
# Field name:DATE_CREATE, field title: Дата создания
# Field name:DATE_MODIFY, field title: Дата изменения
# Field name:MOVED_TIME, field title: MOVED_TIME
# Field name:COMPANY_ID, field title: Компания
# Field name:CONTACT_ID, field title: Контакт
# Field name:CONTACT_IDS, field title: CONTACT_IDS
# Field name:IS_RETURN_CUSTOMER, field title: Повторный лид
# Field name:DATE_CLOSED, field title: Дата завершения
# Field name:ORIGINATOR_ID, field title: Внешний источник
# Field name:ORIGIN_ID, field title: Идентификатор элемента во внешнем источнике
# Field name:UTM_SOURCE, field title: Рекламная система
# Field name:UTM_MEDIUM, field title: Тип трафика
# Field name:UTM_CAMPAIGN, field title: Обозначение рекламной кампании
# Field name:UTM_CONTENT, field title: Содержание кампании
# Field name:UTM_TERM, field title: Условие поиска кампании
# Field name:PHONE, field title: Телефон
# Field name:EMAIL, field title: E-mail
# Field name:WEB, field title: Сайт
# Field name:IM, field title: Мессенджер
# Field name:LINK, field title: LINK
# Field name:UF_CRM_1614774293793, field title: UF_CRM_1614774293793
# Field name:UF_CRM_1614777622, field title: UF_CRM_1614777622
# Field name:UF_SOURCE_AUTO, field title: UF_SOURCE_AUTO
# Field name:UF_CRM_YMCLIENTID, field title: UF_CRM_YMCLIENTID
# Field name:UF_CRM_1628599714, field title: UF_CRM_1628599714
# Field name:UF_CRM_CALLTOUCHLW93, field title: UF_CRM_CALLTOUCHLW93
# Field name:UF_CRM_CALLTOUCHDT_E, field title: UF_CRM_CALLTOUCHDT_E
# Field name:UF_CRM_CALLTOUCHJ7QZ, field title: UF_CRM_CALLTOUCHJ7QZ
# Field name:UF_RECIPIENTS_MAIL, field title: UF_RECIPIENTS_MAIL
# Field name:UF_CLIENT_IP, field title: UF_CLIENT_IP
# Field name:UF_CRM_MGO_CC_ENTRY_ID, field title: UF_CRM_MGO_CC_ENTRY_ID
# Field name:UF_CRM_MGO_CC_CHANNEL_TYPE, field title: UF_CRM_MGO_CC_CHANNEL_TYPE
# Field name:UF_CRM_MGO_CC_RESULT, field title: UF_CRM_MGO_CC_RESULT
# Field name:UF_CRM_MGO_CC_ENTRY_POINT, field title: UF_CRM_MGO_CC_ENTRY_POINT
# Field name:UF_CRM_MGO_CC_CREATE, field title: UF_CRM_MGO_CC_CREATE
# Field name:UF_CRM_MGO_CC_END, field title: UF_CRM_MGO_CC_END
# Field name:UF_CRM_MGO_CC_TAG_ID, field title: UF_CRM_MGO_CC_TAG_ID
# =========================
# Company fields:
# =========================
# Field name:ID, field title: ID
# Field name:TITLE, field title: Название компании
# Field name:COMPANY_TYPE, field title: Тип компании
# Field name:LOGO, field title: Логотип
# Field name:ADDRESS, field title: Фактический адрес
# Field name:ADDRESS_2, field title: Адрес (стр. 2)
# Field name:ADDRESS_CITY, field title: Город
# Field name:ADDRESS_POSTAL_CODE, field title: Почтовый индекс
# Field name:ADDRESS_REGION, field title: Район
# Field name:ADDRESS_PROVINCE, field title: Область
# Field name:ADDRESS_COUNTRY, field title: Страна
# Field name:ADDRESS_COUNTRY_CODE, field title: Код страны
# Field name:ADDRESS_LOC_ADDR_ID, field title: Идентификатор адреса местоположения
# Field name:ADDRESS_LEGAL, field title: Юридический адрес
# Field name:REG_ADDRESS, field title: Юридический адрес
# Field name:REG_ADDRESS_2, field title: Юридический адрес (стр. 2)
# Field name:REG_ADDRESS_CITY, field title: Юридический адрес город
# Field name:REG_ADDRESS_POSTAL_CODE, field title: Юридический адрес почтовый индекс
# Field name:REG_ADDRESS_REGION, field title: Юридический адрес район
# Field name:REG_ADDRESS_PROVINCE, field title: Юридический адрес область
# Field name:REG_ADDRESS_COUNTRY, field title: Юридический адрес страна
# Field name:REG_ADDRESS_COUNTRY_CODE, field title: Юридический адрес код страны
# Field name:REG_ADDRESS_LOC_ADDR_ID, field title: Юридический адрес идентификатор адреса местоположения
# Field name:BANKING_DETAILS, field title: Банковские реквизиты
# Field name:INDUSTRY, field title: Сфера деятельности
# Field name:EMPLOYEES, field title: Кол-во сотрудников
# Field name:CURRENCY_ID, field title: Валюта
# Field name:REVENUE, field title: Годовой оборот
# Field name:OPENED, field title: Доступна для всех
# Field name:COMMENTS, field title: Комментарий
# Field name:HAS_PHONE, field title: Задан телефон
# Field name:HAS_EMAIL, field title: Задан e-mail
# Field name:HAS_IMOL, field title: Задана открытая линия
# Field name:IS_MY_COMPANY, field title: Моя компания
# Field name:ASSIGNED_BY_ID, field title: Ответственный
# Field name:CREATED_BY_ID, field title: Кем создана
# Field name:MODIFY_BY_ID, field title: Кем изменена
# Field name:DATE_CREATE, field title: Дата создания
# Field name:DATE_MODIFY, field title: Дата изменения
# Field name:CONTACT_ID, field title: Контакт
# Field name:LEAD_ID, field title: Лид
# Field name:ORIGINATOR_ID, field title: Внешний источник
# Field name:ORIGIN_ID, field title: Идентификатор элемента во внешнем источнике
# Field name:ORIGIN_VERSION, field title: Версия оригинала
# Field name:UTM_SOURCE, field title: Рекламная система
# Field name:UTM_MEDIUM, field title: Тип трафика
# Field name:UTM_CAMPAIGN, field title: Обозначение рекламной кампании
# Field name:UTM_CONTENT, field title: Содержание кампании
# Field name:UTM_TERM, field title: Условие поиска кампании
# Field name:PHONE, field title: Телефон
# Field name:EMAIL, field title: E-mail
# Field name:WEB, field title: Сайт
# Field name:IM, field title: Мессенджер
# Field name:LINK, field title: LINK
# Field name:UF_CRM_1613564473, field title: UF_CRM_1613564473
# Field name:UF_CRM_1613564489, field title: UF_CRM_1613564489
# Field name:UF_CRM_1613564504, field title: UF_CRM_1613564504
# Field name:UF_CRM_1613564598, field title: UF_CRM_1613564598
# Field name:UF_CRM_1613564653, field title: UF_CRM_1613564653
# Field name:UF_CRM_1613564671, field title: UF_CRM_1613564671
# Field name:UF_CRM_1613564690, field title: UF_CRM_1613564690
# Field name:UF_CRM_1613579289, field title: UF_CRM_1613579289
# Field name:UF_CRM_1613579308, field title: UF_CRM_1613579308
# Field name:UF_CRM_1613581925, field title: UF_CRM_1613581925
# Field name:UF_CRM_1615484041, field title: UF_CRM_1615484041
# Field name:UF_CRM_1615484138, field title: UF_CRM_1615484138
# Field name:UF_CRM_1615800381, field title: UF_CRM_1615800381
# Field name:UF_CRM_1618300661, field title: UF_CRM_1618300661
# Field name:UF_CONTRAGENT_1C, field title: UF_CONTRAGENT_1C
# Field name:UF_SOURCE_AUTO, field title: UF_SOURCE_AUTO
# Field name:UF_CRM_60798DD0821C1, field title: UF_CRM_60798DD0821C1
# Field name:UF_CRM_60CB34DC62704, field title: UF_CRM_60CB34DC62704
# Field name:UF_CRM_60CB34DC7157D, field title: UF_CRM_60CB34DC7157D
# Field name:UF_CRM_60CB34DC7EEDA, field title: UF_CRM_60CB34DC7EEDA
# Field name:UF_PREV_RESPONSIBLE, field title: UF_PREV_RESPONSIBLE
# Field name:UF_CRM_625FEB037FE20, field title: UF_CRM_625FEB037FE20
# Field name:UF_CRM_625FEB0390BC0, field title: UF_CRM_625FEB0390BC0
# Field name:UF_CRM_625FEB039F1C6, field title: UF_CRM_625FEB039F1C6
# Field name:UF_CRM_625FEB03AD944, field title: UF_CRM_625FEB03AD944
# Field name:UF_CRM_1679050701977, field title: UF_CRM_1679050701977
# =========================
# Contact fields:
# =========================
# Field name:ID, field title: ID
# Field name:HONORIFIC, field title: Обращение
# Field name:NAME, field title: Имя
# Field name:SECOND_NAME, field title: Отчество
# Field name:LAST_NAME, field title: Фамилия
# Field name:PHOTO, field title: Фотография
# Field name:BIRTHDATE, field title: Дата рождения
# Field name:TYPE_ID, field title: Тип контакта
# Field name:SOURCE_ID, field title: Источник
# Field name:SOURCE_DESCRIPTION, field title: Дополнительно об источнике
# Field name:POST, field title: Должность
# Field name:ADDRESS, field title: Адрес
# Field name:ADDRESS_2, field title: Адрес (стр. 2)
# Field name:ADDRESS_CITY, field title: Город
# Field name:ADDRESS_POSTAL_CODE, field title: Почтовый индекс
# Field name:ADDRESS_REGION, field title: Район
# Field name:ADDRESS_PROVINCE, field title: Область
# Field name:ADDRESS_COUNTRY, field title: Страна
# Field name:ADDRESS_COUNTRY_CODE, field title: Код страны
# Field name:ADDRESS_LOC_ADDR_ID, field title: Идентификатор адреса местоположения
# Field name:COMMENTS, field title: Комментарий
# Field name:OPENED, field title: Доступен для всех
# Field name:EXPORT, field title: Участвует в экспорте контактов
# Field name:HAS_PHONE, field title: Задан телефон
# Field name:HAS_EMAIL, field title: Задан e-mail
# Field name:HAS_IMOL, field title: Задана открытая линия
# Field name:ASSIGNED_BY_ID, field title: Ответственный
# Field name:CREATED_BY_ID, field title: Кем создан
# Field name:MODIFY_BY_ID, field title: Кем изменен
# Field name:DATE_CREATE, field title: Дата создания
# Field name:DATE_MODIFY, field title: Дата изменения
# Field name:COMPANY_ID, field title: Компания
# Field name:COMPANY_IDS, field title: COMPANY_IDS
# Field name:LEAD_ID, field title: Лид
# Field name:ORIGINATOR_ID, field title: Внешний источник
# Field name:ORIGIN_ID, field title: Идентификатор элемента во внешнем источнике
# Field name:ORIGIN_VERSION, field title: Версия оригинала
# Field name:FACE_ID, field title: Привязка к лицам из модуля faceid
# Field name:UTM_SOURCE, field title: Рекламная система
# Field name:UTM_MEDIUM, field title: Тип трафика
# Field name:UTM_CAMPAIGN, field title: Обозначение рекламной кампании
# Field name:UTM_CONTENT, field title: Содержание кампании
# Field name:UTM_TERM, field title: Условие поиска кампании
# Field name:PHONE, field title: Телефон
# Field name:EMAIL, field title: E-mail
# Field name:WEB, field title: Сайт
# Field name:IM, field title: Мессенджер
# Field name:LINK, field title: LINK
# Field name:UF_SOURCE_AUTO, field title: UF_SOURCE_AUTO
# Field name:UF_CRM_6076D30B3026C, field title: UF_CRM_6076D30B3026C
# Field name:UF_CRM_60DC31D6E6C64, field title: UF_CRM_60DC31D6E6C64
# Field name:UF_CRM_60DC31D6F254D, field title: UF_CRM_60DC31D6F254D
# Field name:UF_CRM_60DC31D7086E4, field title: UF_CRM_60DC31D7086E4
# Field name:UF_CRM_YMCLIENTID, field title: UF_CRM_YMCLIENTID
# Field name:UF_CRM_611281DCE25DC, field title: UF_CRM_611281DCE25DC
# Field name:UF_PREV_RESPONSIBLE, field title: UF_PREV_RESPONSIBLE
# Field name:UF_CRM_ZOOMKITYMCIDS, field title: UF_CRM_ZOOMKITYMCIDS
# Field name:UF_CRM_CALLTOUCH_U5Y, field title: UF_CRM_CALLTOUCH_U5Y
# Field name:UF_CRM_CALLTOUCHDB3_, field title: UF_CRM_CALLTOUCHDB3_
# Field name:UF_CRM_CALLTOUCHKEV1, field title: UF_CRM_CALLTOUCHKEV1
# Field name:UF_CRM_62FE345E69341, field title: UF_CRM_62FE345E69341
# Field name:UF_CRM_62FE492BD7C4E, field title: UF_CRM_62FE492BD7C4E
# Field name:UF_CRM_638F04F45D392, field title: UF_CRM_638F04F45D392
# Field name:UF_CRM_638F04F48DBF4, field title: UF_CRM_638F04F48DBF4
# Field name:UF_CRM_638F04F4BA680, field title: UF_CRM_638F04F4BA680
# Field name:UF_CRM_638F04F4E8A0B, field title: UF_CRM_638F04F4E8A0B
# Field name:UF_CRM_638F04F524648, field title: UF_CRM_638F04F524648
# Field name:UF_CRM_638F04F55167F, field title: UF_CRM_638F04F55167F
# Field name:UF_CRM_638F04F5802AA, field title: UF_CRM_638F04F5802AA
# Field name:UF_CRM_BANKING_DETAILS, field title: UF_CRM_BANKING_DETAILS
# Field name:UF_CRM_REVENUE, field title: UF_CRM_REVENUE
# Field name:UF_CRM_LOGO, field title: UF_CRM_LOGO
# Field name:UF_CRM_TITLE, field title: UF_CRM_TITLE
# Field name:UF_CRM_ADDRESS_LEGAL, field title: UF_CRM_ADDRESS_LEGAL
# Field name:UF_CRM_CURRENCY_ID, field title: UF_CRM_CURRENCY_ID
# Field name:UF_CRM_EMPLOYEES, field title: UF_CRM_EMPLOYEES
# Field name:UF_CRM_INDUSTRY, field title: UF_CRM_INDUSTRY
# Field name:UF_CRM_COMPANY_TYPE, field title: UF_CRM_COMPANY_TYPE
# Field name:UF_CRM_1613564653, field title: UF_CRM_1613564653
# Field name:UF_CRM_60CB34DC7157D, field title: UF_CRM_60CB34DC7157D
# Field name:UF_CRM_60CB34DC62704, field title: UF_CRM_60CB34DC62704
# Field name:UF_CRM_60CB34DC7EEDA, field title: UF_CRM_60CB34DC7EEDA
# Field name:UF_CRM_1613564504, field title: UF_CRM_1613564504
# Field name:UF_CRM_1615484138, field title: UF_CRM_1615484138
# Field name:UF_CRM_1613564489, field title: UF_CRM_1613564489
# Field name:UF_CRM_1613579289, field title: UF_CRM_1613579289
# Field name:UF_CRM_1613579308, field title: UF_CRM_1613579308
# Field name:UF_CRM_1618300661, field title: UF_CRM_1618300661
# Field name:UF_CRM_CONTACT_ID, field title: UF_CRM_CONTACT_ID
# Field name:UF_CRM_UF_CONTRAGENT_1C, field title: UF_CRM_UF_CONTRAGENT_1C
# Field name:UF_CRM_1613581925, field title: UF_CRM_1613581925
# Field name:UF_CRM_60798DD0821C1, field title: UF_CRM_60798DD0821C1
# Field name:UF_CRM_1615800381, field title: UF_CRM_1615800381
# Field name:UF_CRM_1613564473, field title: UF_CRM_1613564473
# Field name:UF_CRM_1613564690, field title: UF_CRM_1613564690
# Field name:UF_CRM_1613564598, field title: UF_CRM_1613564598
# Field name:UF_CRM_1613564671, field title: UF_CRM_1613564671
# Field name:UF_CRM_1615484041, field title: UF_CRM_1615484041
# =========================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/m9/g7bq03fn7mz049ysy79cfr500000gn/T/ipykernel_62908/2591633839.py in <module>
#      27
#      28 if __name__ == "__main__":
# ---> 29     show_values()
#
# NameError: name 'show_values' is not defined
